# %%
import torch
import numpy as np

# %%
from torch import nn

# %%
linear_layer = nn.Linear(in_features=3,out_features=1)

# %%
linear_layer.weight
# Out:
# Parameter containing:
# tensor([[ 0.1806, -0.0349, -0.1638]], requires_grad=True)

# %%
linear_layer.bias
# Out:
# Parameter containing:
# tensor([-0.2685], requires_grad=True)

# %%
linear_layer(torch.tensor([1,2,3],dtype=torch.float32))
# Out:
# tensor([-0.6490], grad_fn=<AddBackward0>)

# %%
0.1806*1 - 0.0349*2 - 0.1638*3 -0.2685
# Out:
# -0.6491

# %%
linear_layer(torch.tensor([4,5,6],dtype=torch.float32))
# Out:
# tensor([-0.7031], grad_fn=<AddBackward0>)

# %%
(0.1806*4 - 0.0349*5 - 0.1638*6) - 0.2685
# Out:
# -0.7034

# %%
torch.relu(torch.tensor(-50,dtype=torch.float32))
# Out:
# tensor(0.)

# %%
relu = nn.ReLU()

# %%
relu(torch.tensor(50,dtype=torch.float32))
# Out:
# tensor(50.)
